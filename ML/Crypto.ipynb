# %%
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv("/Users/danny/Documents/ML/Datasets/coin_Ethereum.csv")

# %%
df.head()
# Out:
#    SNo      Name Symbol                 Date      High       Low      Open  \
# 0    1  Ethereum    ETH  2015-08-08 23:59:59  2.798810  0.714725  2.793760
# 1    2  Ethereum    ETH  2015-08-09 23:59:59  0.879810  0.629191  0.706136
# 2    3  Ethereum    ETH  2015-08-10 23:59:59  0.729854  0.636546  0.713989
# 3    4  Ethereum    ETH  2015-08-11 23:59:59  1.131410  0.663235  0.708087
# 4    5  Ethereum    ETH  2015-08-12 23:59:59  1.289940  0.883608  1.058750
#
#       Close     Volume     Marketcap
# 0  0.753325   674188.0  4.548689e+07
# 1  0.701897   532170.0  4.239957e+07
# 2  0.708448   405283.0  4.281836e+07
# 3  1.067860  1463100.0  6.456929e+07
# 4  1.217440  2150620.0  7.364501e+07

# %%
df.shape
# Out:
# (2160, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2160 non-null   int64
#  1   Name       2160 non-null   object
#  2   Symbol     2160 non-null   object
#  3   Date       2160 non-null   object
#  4   High       2160 non-null   float64
#  5   Low        2160 non-null   float64
#  6   Open       2160 non-null   float64
#  7   Close      2160 non-null   float64
#  8   Volume     2160 non-null   float64
#  9   Marketcap  2160 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 168.9+ KB

# %%
df.isnull()
# Out:
#         SNo   Name  Symbol   Date   High    Low   Open  Close  Volume  \
# 0     False  False   False  False  False  False  False  False   False
# 1     False  False   False  False  False  False  False  False   False
# 2     False  False   False  False  False  False  False  False   False
# 3     False  False   False  False  False  False  False  False   False
# 4     False  False   False  False  False  False  False  False   False
# ...     ...    ...     ...    ...    ...    ...    ...    ...     ...
# 2155  False  False   False  False  False  False  False  False   False
# 2156  False  False   False  False  False  False  False  False   False
# 2157  False  False   False  False  False  False  False  False   False
# 2158  False  False   False  False  False  False  False  False   False
# 2159  False  False   False  False  False  False  False  False   False
#
#       Marketcap
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# ...

# %%
df.isnull().sum()
# Out:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Name
# Ethereum    2160
# Name: count, dtype: int64

# %%
df["Date"].value_counts()
# Out:
# Date
# 2015-08-08 23:59:59    1
# 2019-07-13 23:59:59    1
# 2019-07-27 23:59:59    1
# 2019-07-26 23:59:59    1
# 2019-07-25 23:59:59    1
#                       ..
# 2017-07-22 23:59:59    1
# 2017-07-21 23:59:59    1
# 2017-07-20 23:59:59    1
# 2017-07-19 23:59:59    1
# 2021-07-06 23:59:59    1
# Name: count, Length: 2160, dtype: int64

# %%
df.index= pd.to_datetime(df.Date)

# %%
df.head()
# Out:
#                      SNo      Name Symbol                 Date      High  \
# Date
# 2015-08-08 23:59:59    1  Ethereum    ETH  2015-08-08 23:59:59  2.798810
# 2015-08-09 23:59:59    2  Ethereum    ETH  2015-08-09 23:59:59  0.879810
# 2015-08-10 23:59:59    3  Ethereum    ETH  2015-08-10 23:59:59  0.729854
# 2015-08-11 23:59:59    4  Ethereum    ETH  2015-08-11 23:59:59  1.131410
# 2015-08-12 23:59:59    5  Ethereum    ETH  2015-08-12 23:59:59  1.289940
#
#                           Low      Open     Close     Volume     Marketcap
# Date
# 2015-08-08 23:59:59  0.714725  2.793760  0.753325   674188.0  4.548689e+07
# 2015-08-09 23:59:59  0.629191  0.706136  0.701897   532170.0  4.239957e+07
# 2015-08-10 23:59:59  0.636546  0.713989  0.708448   405283.0  4.281836e+07
# 2015-08-11 23:59:59  0.663235  0.708087  1.067860  1463100.0  6.456929e+07
# 2015-08-12 23:59:59  0.883608  1.058750  1.217440  2150620.0  7.364501e+07

# %%
df.drop(['SNo','Name','Symbol','Volume','Marketcap'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                     Date      High       Low      Open  \
# Date
# 2015-08-08 23:59:59  2015-08-08 23:59:59  2.798810  0.714725  2.793760
# 2015-08-09 23:59:59  2015-08-09 23:59:59  0.879810  0.629191  0.706136
# 2015-08-10 23:59:59  2015-08-10 23:59:59  0.729854  0.636546  0.713989
# 2015-08-11 23:59:59  2015-08-11 23:59:59  1.131410  0.663235  0.708087
# 2015-08-12 23:59:59  2015-08-12 23:59:59  1.289940  0.883608  1.058750
#
#                         Close
# Date
# 2015-08-08 23:59:59  0.753325
# 2015-08-09 23:59:59  0.701897
# 2015-08-10 23:59:59  0.708448
# 2015-08-11 23:59:59  1.067860
# 2015-08-12 23:59:59  1.217440

# %%
df.drop(['Date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                          High       Low      Open     Close
# Date
# 2015-08-08 23:59:59  2.798810  0.714725  2.793760  0.753325
# 2015-08-09 23:59:59  0.879810  0.629191  0.706136  0.701897
# 2015-08-10 23:59:59  0.729854  0.636546  0.713989  0.708448
# 2015-08-11 23:59:59  1.131410  0.663235  0.708087  1.067860
# 2015-08-12 23:59:59  1.289940  0.883608  1.058750  1.217440

# %%
def create_features(df):
    df['dayofweek']= df.index.day_of_week
    df['month']=df.index.month
    df['dayofyear']=df.index.day_of_year
    
    return df

# %%
df=create_features(df)

# %%
df.head()
# Out:
#                          High       Low      Open     Close  dayofweek  month  \
# Date
# 2015-08-08 23:59:59  2.798810  0.714725  2.793760  0.753325          5      8
# 2015-08-09 23:59:59  0.879810  0.629191  0.706136  0.701897          6      8
# 2015-08-10 23:59:59  0.729854  0.636546  0.713989  0.708448          0      8
# 2015-08-11 23:59:59  1.131410  0.663235  0.708087  1.067860          1      8
# 2015-08-12 23:59:59  1.289940  0.883608  1.058750  1.217440          2      8
#
#                      dayofyear
# Date
# 2015-08-08 23:59:59        220
# 2015-08-09 23:59:59        221
# 2015-08-10 23:59:59        222
# 2015-08-11 23:59:59        223
# 2015-08-12 23:59:59        224

# %% [markdown]
# Analysis

# %%
import seaborn as sns

# %%
sns.histplot(data=df,x=df.index,y='Close')
plt.show()

# %%
df.head()
# Out:
#                          High       Low      Open     Close  dayofweek  month  \
# Date
# 2015-08-08 23:59:59  2.798810  0.714725  2.793760  0.753325          5      8
# 2015-08-09 23:59:59  0.879810  0.629191  0.706136  0.701897          6      8
# 2015-08-10 23:59:59  0.729854  0.636546  0.713989  0.708448          0      8
# 2015-08-11 23:59:59  1.131410  0.663235  0.708087  1.067860          1      8
# 2015-08-12 23:59:59  1.289940  0.883608  1.058750  1.217440          2      8
#
#                      dayofyear
# Date
# 2015-08-08 23:59:59        220
# 2015-08-09 23:59:59        221
# 2015-08-10 23:59:59        222
# 2015-08-11 23:59:59        223
# 2015-08-12 23:59:59        224

# %%
df.tail()
# Out:
#                             High          Low         Open        Close  \
# Date
# 2021-07-02 23:59:59  2155.596496  2021.824808  2109.892677  2150.040364
# 2021-07-03 23:59:59  2237.567155  2117.590013  2150.835025  2226.114282
# 2021-07-04 23:59:59  2384.286857  2190.837703  2226.550382  2321.724112
# 2021-07-05 23:59:59  2321.922836  2163.041394  2321.922836  2198.582464
# 2021-07-06 23:59:59  2346.294874  2197.919385  2197.919385  2324.679449
#
#                      dayofweek  month  dayofyear
# Date
# 2021-07-02 23:59:59          4      7        183
# 2021-07-03 23:59:59          5      7        184
# 2021-07-04 23:59:59          6      7        185
# 2021-07-05 23:59:59          0      7        186
# 2021-07-06 23:59:59          1      7        187

# %%
df_new= pd.read_csv("/Users/danny/Documents/ML/Datasets/Ethereum_Historical_Data.csv")

# %%
df_new.head()
# Out:
#       Date    Price     Open     High      Low     Vol. Change %
# 0  2/26/25  2481.15  2496.06  2507.13  2472.58  990.21K   -0.60%
# 1  2/25/25  2496.06  2511.04  2533.18  2339.46    1.44M   -0.59%
# 2  2/24/25  2510.94  2819.69  2838.22  2493.73  959.09K  -10.95%
# 3  2/23/25  2819.69  2763.23  2837.98  2745.96  655.96K    2.04%
# 4  2/22/25  2763.23  2662.35  2795.29  2654.73  485.01K    3.79%

# %%
df_new.tail()
# Out:
#          Date    Price     Open     High      Low     Vol. Change %
# 1295  8/11/21  3163.66  3140.86  3269.70  3122.67  950.12K    0.73%
# 1296  8/10/21  3140.71  3162.81  3232.02  3057.84    1.12M   -0.70%
# 1297   8/9/21  3162.93  3011.88  3184.84  2899.24    1.44M    5.01%
# 1298   8/8/21  3012.07  3158.30  3188.49  2949.66    1.25M   -4.62%
# 1299   8/7/21  3158.00  2889.58  3169.74  2867.58   64.84K    9.29%

# %%
df_new= df_new.iloc[::-1].reset_index(drop = True)

# %%
df.head()
# Out:
#                          High       Low      Open     Close  dayofweek  month  \
# Date
# 2015-08-08 23:59:59  2.798810  0.714725  2.793760  0.753325          5      8
# 2015-08-09 23:59:59  0.879810  0.629191  0.706136  0.701897          6      8
# 2015-08-10 23:59:59  0.729854  0.636546  0.713989  0.708448          0      8
# 2015-08-11 23:59:59  1.131410  0.663235  0.708087  1.067860          1      8
# 2015-08-12 23:59:59  1.289940  0.883608  1.058750  1.217440          2      8
#
#                      dayofyear
# Date
# 2015-08-08 23:59:59        220
# 2015-08-09 23:59:59        221
# 2015-08-10 23:59:59        222
# 2015-08-11 23:59:59        223
# 2015-08-12 23:59:59        224

# %%
df_new.index =pd.to_datetime(df_new["Date"])
# Out:
# /var/folders/jh/gvq3hptd3gv9nnmv_fj5m63w0000gn/T/ipykernel_10896/2318013776.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_new.index =pd.to_datetime(df_new["Date"])

# %%
df_new.head()
# Out:
#                Date    Price     Open     High      Low     Vol. Change %
# Date
# 2021-08-07   8/7/21  3158.00  2889.58  3169.74  2867.58   64.84K    9.29%
# 2021-08-08   8/8/21  3012.07  3158.30  3188.49  2949.66    1.25M   -4.62%
# 2021-08-09   8/9/21  3162.93  3011.88  3184.84  2899.24    1.44M    5.01%
# 2021-08-10  8/10/21  3140.71  3162.81  3232.02  3057.84    1.12M   -0.70%
# 2021-08-11  8/11/21  3163.66  3140.86  3269.70  3122.67  950.12K    0.73%

# %%
df_new.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Change %'], dtype='object')

# %%
df_new.head()
# Out:
#                Date    Price     Open     High      Low     Vol. Change %
# Date
# 2021-08-07   8/7/21  3158.00  2889.58  3169.74  2867.58   64.84K    9.29%
# 2021-08-08   8/8/21  3012.07  3158.30  3188.49  2949.66    1.25M   -4.62%
# 2021-08-09   8/9/21  3162.93  3011.88  3184.84  2899.24    1.44M    5.01%
# 2021-08-10  8/10/21  3140.71  3162.81  3232.02  3057.84    1.12M   -0.70%
# 2021-08-11  8/11/21  3163.66  3140.86  3269.70  3122.67  950.12K    0.73%

# %%
df_new.rename(columns={'Price' : 'Close'},inplace=True)

# %%
df_new.head()
# Out:
#                Date    Close     Open     High      Low     Vol. Change %
# Date
# 2021-08-07   8/7/21  3158.00  2889.58  3169.74  2867.58   64.84K    9.29%
# 2021-08-08   8/8/21  3012.07  3158.30  3188.49  2949.66    1.25M   -4.62%
# 2021-08-09   8/9/21  3162.93  3011.88  3184.84  2899.24    1.44M    5.01%
# 2021-08-10  8/10/21  3140.71  3162.81  3232.02  3057.84    1.12M   -0.70%
# 2021-08-11  8/11/21  3163.66  3140.86  3269.70  3122.67  950.12K    0.73%

# %%
df_new.drop(['Vol.','Change %'],axis=1,inplace=True)

# %%
df_new.head()
# Out:
#                Date    Close     Open     High      Low
# Date
# 2021-08-07   8/7/21  3158.00  2889.58  3169.74  2867.58
# 2021-08-08   8/8/21  3012.07  3158.30  3188.49  2949.66
# 2021-08-09   8/9/21  3162.93  3011.88  3184.84  2899.24
# 2021-08-10  8/10/21  3140.71  3162.81  3232.02  3057.84
# 2021-08-11  8/11/21  3163.66  3140.86  3269.70  3122.67

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1300 entries, 2021-08-07 to 2025-02-26
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1300 non-null   object
#  1   Close   1300 non-null   float64
#  2   Open    1300 non-null   float64
#  3   High    1300 non-null   float64
#  4   Low     1300 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 60.9+ KB

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1300 entries, 2021-08-07 to 2025-02-26
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1300 non-null   object
#  1   Close   1300 non-null   float64
#  2   Open    1300 non-null   float64
#  3   High    1300 non-null   float64
#  4   Low     1300 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 60.9+ KB

# %%
df_new.index=pd.to_datetime(df_new['Date'])
# Out:
# /var/folders/jh/gvq3hptd3gv9nnmv_fj5m63w0000gn/T/ipykernel_10896/3244255480.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_new.index=pd.to_datetime(df_new['Date'])

# %%
df_new.head()
# Out:
#                Date    Close     Open     High      Low
# Date
# 2021-08-07   8/7/21  3158.00  2889.58  3169.74  2867.58
# 2021-08-08   8/8/21  3012.07  3158.30  3188.49  2949.66
# 2021-08-09   8/9/21  3162.93  3011.88  3184.84  2899.24
# 2021-08-10  8/10/21  3140.71  3162.81  3232.02  3057.84
# 2021-08-11  8/11/21  3163.66  3140.86  3269.70  3122.67

# %%
df_new.drop('Date',axis=1,inplace=True)

# %%
df_new.head()
# Out:
#               Close     Open     High      Low
# Date
# 2021-08-07  3158.00  2889.58  3169.74  2867.58
# 2021-08-08  3012.07  3158.30  3188.49  2949.66
# 2021-08-09  3162.93  3011.88  3184.84  2899.24
# 2021-08-10  3140.71  3162.81  3232.02  3057.84
# 2021-08-11  3163.66  3140.86  3269.70  3122.67

# %%
df_new=create_features(df_new)

# %%
df_new.head()
# Out:
#               Close     Open     High      Low  dayofweek  month  dayofyear
# Date
# 2021-08-07  3158.00  2889.58  3169.74  2867.58          5      8        219
# 2021-08-08  3012.07  3158.30  3188.49  2949.66          6      8        220
# 2021-08-09  3162.93  3011.88  3184.84  2899.24          0      8        221
# 2021-08-10  3140.71  3162.81  3232.02  3057.84          1      8        222
# 2021-08-11  3163.66  3140.86  3269.70  3122.67          2      8        223

# %% [markdown]
# Model Training

# %%
features=['Open','High','Low','dayofweek','month','dayofyear']
target=['Close']

# %%
x_train=df[features]
y_train=df[target]

x_test=df_new[features]
y_test=df_new[target]

# %%
import xgboost as xgb
